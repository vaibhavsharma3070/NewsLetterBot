# %%
import csv
import pandas as pd
import random
import imaplib
import email
import json
import asyncio
from logging import exception
from selenium import webdriver
from selenium.webdriver.firefox.service import Service as FirefoxService
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
import time
from selenium.webdriver.common.action_chains import ActionChains
# from fake_useragent import UserAgent
import multiprocessing
import random
import getpass
import imaplib
import email

def driver_initiate():
    options = webdriver.ChromeOptions()
    
    options.add_argument("--disable-gpu")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    options.add_argument("start-maximized")
    options.add_argument("--disable-browser-side-navigation")
    options.add_argument("--profile-directory=Default")
    options.add_argument("--ignore-ssl-errors=yes")
    options.add_argument("--ignore-certificate-errors")
    
    driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()), options=options)
    return driver

def gmail_login(driver):
    driver.get('https://accounts.google.com/InteractiveLogin/identifier?continue=https%3A%2F%2Fmail.google.com%2Fmail%2Fu%2F0%2F&emr=1&followup=https%3A%2F%2Fmail.google.com%2Fmail%2Fu%2F0%2F&osid=1&passive=1209600&service=mail&ifkv=AWnogHdmuTEUXljv8o_n-oXL-T90nqunGbn45JTOZixd13aHYShcmluhMkDYjNr_FpiHpcq_sVkJ&flowName=GlifWebSignIn&flowEntry=ServiceLogin')

    try:
        turnon = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, f' //div[contains(text(), "Use another account")]')))
        turnon.click()
    except:
        pass

    #email
    email = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, '//input[@type="email"]')))
    email.send_keys("admin@meeemail.net")
    button = driver.find_element(By.XPATH, '//span[contains(text(), "Next")]')
    button.click()
    time.sleep(5)

    #password
    pwd = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, '//input[@type="password"]')))
    pwd.send_keys("bEatR2M6aXaV5W")
    button = driver.find_element(By.XPATH, '//span[contains(text(), "Next")]')
    button.click()
    time.sleep(2)

    #refresh
    driver.refresh()
    time.sleep(2)

def unseen_mail():
# login to the mailbox
    mail = imaplib.IMAP4_SSL('imap.gmail.com')
    mail.login('admin@meeemail.net', 'bEatR2M6aXaV5W')

    # select the inbox folder
    mail.select("inbox")

    # search for unseen messages
    result, data = mail.search(None, "UNSEEN")

    # loop through all the unseen messages and print their subjects
    mail_sublist=[]
    for num in data[0].split():
        result, data = mail.fetch(num, "(RFC822)")
        email_message = email.message_from_bytes(data[0][1])
        mail_sublist.append(email_message['subject'])
#         print("UNSEEN mais :", mail_sublist)
        
        
    return mail_sublist
    # close the mailbox connection
#     mail.close()
#     mail.logout()


def client_logic() :
   
    driver=driver_initiate()
    gmail_login(driver)
    # call unseen mail function to see mails 
    unseen_list=unseen_mail()
    # main client logic
    print("----------",unseen_list)
    for i in range(len(unseen_list)-1,-1,-1):
        print("======",i)
        time.sleep(2)
        #find the object based on unseen mail text 
        emails = driver.find_elements(By.XPATH,'//span[@class="bog"]/span')
#         emails = driver.find_element(By.XPATH,f'//*[contains(text(),"{eml}")]')
        print("---------->>>", len(emails))
        subject = emails[i].text
        print("======",subject)

        
        if 'confirmation' in emails[i].text.lower() or 'verify' in emails[i].text.lower() or 'verification' in emails[i].text.lower() or 'confirm' in emails[i].text.lower() :
            emails[i].click()
#             print("Ok")
            time.sleep(5)
            archive = driver.find_elements(By.XPATH,'//div[contains(@class,"asa")]')  
            time.sleep(2)
            archive[12].click()
#             driver.back()
            time.sleep(2)
        else:
            # random generate
            
#             x = random.random()
            x=7
            # conditions 
            if x < 0.1:
                category = "0_5"
                open_rate = 0.05
                CTOR = 0
            elif x > 0.1 and x < 0.3:
                category = "1_5"
                open_rate = 0.2
                CTOR = 0.04
            elif x > 0.3 and x < 0.7:
                category = "2_5"
                open_rate = 0.4
                CTOR = 0.1
            elif x > 0.7 and x < 0.85:
                category = "3_5"
                open_rate = 0.6
                CTOR = 0.15
            elif x > 0.85 and x < 0.95:
                category = "4_5"
                open_rate = 0.8 
                CTOR = 0.2
            else:
                category = "5_5"
                open_rate = 0.95
                CTOR = 0.25
                
            if (x<(1-open_rate)) :
                checkbox = driver.find_element(By.XPATH,'//div[@role="checkbox"]')
                checkbox.click()
                time.sleep(5)
                archive = driver.find_elements(By.XPATH,'//div[contains(@class,"asa")]')
                archive[0].click()
                time.sleep(2)
            else : 
                # Wait for the inbox to load and open first email
                emails = driver.find_element(By.XPATH,'//span[@class="bog"]/span')
                emails.click()


                # Scroll down the webpage using Keys.PAGE_DOWN
                body =  WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, '//div[@class="ip iq"]')))
                driver.execute_script('arguments[0].scrollIntoView()', body)
                time.sleep(4)
                
                if (x < CTOR) : 
                    rows = driver.find_elements(By.XPATH, '//table[@role="grid"]/tbody/tr')
                    rows[0].click()

                    # Find all anchor tags in the email using their tag name
                    anchors = driver.find_elements(By.TAG_NAME, 'a')

                    filtered_anchors = []
                    for anchor in anchors:
                        link_text = anchor.get_attribute('href')
                        if link_text is not None and 'unsubscribe' not in link_text and 'google' not in link_text and link_text!='':
                            filtered_anchors.append(anchor)
                    # print(filtered_anchors)

                    cnt = random.randint(0,len(filtered_anchors)-1)
                    driver.execute_script('arguments[0].scrollIntoView()', filtered_anchors[cnt])
                    time.sleep(5)
                    filtered_anchors[cnt].click()
                    # time.sleep(10)
                    # subscribe = driver.find_element(By.XPATH,'//button[@aria-label="Subscribe"]')
                    time.sleep(5)
                    driver.switch_to.window(driver.window_handles[1])

                    # scroll down slowly in increments of 500 pixels
                    height = driver.execute_script('return document.body.scrollHeight')

                    while height>0:
                        driver.execute_script(f"window.scrollBy(0, 50);")
                        height = height - 50
                        time.sleep(1)
                    # subscribe.click()
                    # time.sleep(5)
                    # Close the webdriver
                    driver.quit()


                    # ==========If (rand()<((0.25-CTOR)/5))==========
                    # Click the unsubscribe link and complete the unsubscribe
                elif If (x<((0.25-CTOR)/5)) :
                    rows = driver.find_elements(By.XPATH, '//table[@role="grid"]/tbody/tr')
                    rows[0].click()

                    anchors = driver.find_elements(By.TAG_NAME, 'a')

#                     filtered_anchors = []
                    for anchor in anchors:
                        link_text = anchor.get_attribute('href')
                        print(link_text)
                        
                        if  link_text is not None and 'Unsubscribe' in link_text:
                            link_text.click()
                            time.sleep(10)
                            print("Ok")
                            
                #Archive
                else : 
                    archive = driver.find_element(By.XPATH,'/html/body/div[7]/div[3]/div/div[2]/div[5]/div/div/div/div/div[1]/div[2]/div[1]/div[1]/div[2]/div[1]')
                    archive.click()
                    time.sleep(2)
                    driver.quit()  
                
                

            print(f"The value {x} belongs to category:{category}, open_rate:{open_rate}, CTOR:{CTOR} ")
            
            
            
client_logic()
# Out:
# ---------- ['=?utf-8?Q?=F0=9F=93=AC=20News=20of=20the=20Day=20for=20March=2028=2C=202023?=', '10 Rules to Make Your Writing so Persuasive People\r\n =?UTF-8?B?Q2Fu4oCZdA==?= Ignore It | Darius Foroux']
# ====== 1
# ---------->>> 4
# ====== News of the Day for March 28, 2023
# The value 7 belongs to category:5_5, open_rate:0.95, CTOR:0.25
# ====== 0
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      94     if err is not None:
# ---> 95         raise err
#      96
#
# ...
